# %%
import pandas as pd
airbnb=pd.read_csv('Airbnb_Texas_Rentals(1).csv',index_col=0)

# %%
airbnb
# Out:
#       average_rate_per_night bedrooms_count             city date_of_listing  \
# 1                        $27              2           Humble        May 2016
# 2                       $149              4      San Antonio   November 2010
# 3                        $59              1          Houston    January 2017
# 4                        $60              1            Bryan   February 2016
# 5                        $75              2       Fort Worth   February 2017
# 6                       $250              4           Conroe     August 2016
# 7                       $129              3      Cedar Creek      March 2016
# 8                        $25              1       Fort Worth    January 2016
# 9                       $345              3         Rockport   February 2016
# 10                       $72         Studio      San Antonio     August 2013
# 11                       $65              1           Irving       July 2015
# ...

# %%
airbnb.head()
# Out:
#   average_rate_per_night bedrooms_count         city date_of_listing  \
# 1                    $27              2       Humble        May 2016
# 2                   $149              4  San Antonio   November 2010
# 3                    $59              1      Houston    January 2017
# 4                    $60              1        Bryan   February 2016
# 5                    $75              2   Fort Worth   February 2017
#
#                                          description   latitude  longitude  \
# 1  Welcome to stay in private room with queen bed...  30.020138 -95.293996
# 2  Stylish, fully remodeled home in upscale NW – ...  29.503068 -98.447688
# 3  'River house on island close to the city' \nA ...  29.829352 -95.081549
# 4  Private bedroom in a cute little home situated...  30.637304 -96.337846
# 5  Welcome to our original 1920's home. We recent...  32.747097 -97.286434
#
#                                                title  \
# ...

# %%
#Q2
airbnb['average_rate_per_night'].isnull().any()
# Out:
# True

# %%
#Q3
airbnb[airbnb['average_rate_per_night'].isnull()]
# Out:
#      average_rate_per_night bedrooms_count            city date_of_listing  \
# 26                      NaN              2     San Antonio       July 2014
# 104                     NaN              1           Mexia      March 2017
# 105                     NaN              1      Fort Worth  September 2015
# 106                     NaN              1       Galveston  September 2016
# 168                     NaN              1  Fredericksburg   February 2016
# 170                     NaN              1          Austin   February 2016
# 171                     NaN         Studio   Chappell Hill     August 2016
# 172                     NaN              1     San Antonio       July 2016
# 173                     NaN              1        Richmond     August 2016
# 178                     NaN         Studio          Conroe    October 2015
# 180                     NaN              1         Abilene      March 2015
# ...

# %%
#Q4
airbnb[airbnb['bedrooms_count'].isnull()]
# Out:
#       average_rate_per_night bedrooms_count        city date_of_listing  \
# 6876                    $125            NaN  Pipe Creek        May 2013
# 14238                    $89            NaN      Austin      April 2009
# 16812                    $70            NaN     Houston   November 2014
#
#                                              description   latitude  \
# 6876   Experience gentile hospitality extended to you...  29.682444
# 14238  Great studio apartment, perfect for couples or...  30.248291
# 16812  Walk to restaurants and shops, bike to the Art...  29.786767
#
#        longitude                              title  \
# 6876  -98.973700    Texas Hill Country River Estate
# 14238 -97.737262      Gem of a Studio near Downtown
# 16812 -95.396320  Houston Heights Inviting Get-Away
#
#                                                      url
# 6876   https://www.airbnb.com/rooms/1487430?location=...
# 14238  https://www.airbnb.com/rooms/6413?location=Aus...
# ...

# %%
#Q5
airbnb.dropna(subset=['average_rate_per_night','bedrooms_count'],inplace=True)

# %%
airbnb
# Out:
#       average_rate_per_night bedrooms_count             city date_of_listing  \
# 1                        $27              2           Humble        May 2016
# 2                       $149              4      San Antonio   November 2010
# 3                        $59              1          Houston    January 2017
# 4                        $60              1            Bryan   February 2016
# 5                        $75              2       Fort Worth   February 2017
# 6                       $250              4           Conroe     August 2016
# 7                       $129              3      Cedar Creek      March 2016
# 8                        $25              1       Fort Worth    January 2016
# 9                       $345              3         Rockport   February 2016
# 10                       $72         Studio      San Antonio     August 2013
# 11                       $65              1           Irving       July 2015
# ...

# %%
airbnb[['average_rate_per_night','bedrooms_count']].isnull().any()
# Out:
# average_rate_per_night    False
# bedrooms_count            False
# dtype: bool

# %%
#Q6
airbnb[['city','date_of_listing','description','title','url']]=airbnb[['city','date_of_listing','description','title','url']].fillna('Not Available')

# %%
airbnb
# Out:
#       average_rate_per_night bedrooms_count             city date_of_listing  \
# 1                        $27              2           Humble        May 2016
# 2                       $149              4      San Antonio   November 2010
# 3                        $59              1          Houston    January 2017
# 4                        $60              1            Bryan   February 2016
# 5                        $75              2       Fort Worth   February 2017
# 6                       $250              4           Conroe     August 2016
# 7                       $129              3      Cedar Creek      March 2016
# 8                        $25              1       Fort Worth    January 2016
# 9                       $345              3         Rockport   February 2016
# 10                       $72         Studio      San Antonio     August 2013
# 11                       $65              1           Irving       July 2015
# ...

# %%
#Q7
airbnb['average_rate_per_night']=airbnb['average_rate_per_night'].str.replace('$','').astype(int)

# %%
airbnb.head()
# Out:
#    average_rate_per_night bedrooms_count         city date_of_listing  \
# 1                      27              2       Humble        May 2016
# 2                     149              4  San Antonio   November 2010
# 3                      59              1      Houston    January 2017
# 4                      60              1        Bryan   February 2016
# 5                      75              2   Fort Worth   February 2017
#
#                                          description   latitude  longitude  \
# 1  Welcome to stay in private room with queen bed...  30.020138 -95.293996
# 2  Stylish, fully remodeled home in upscale NW – ...  29.503068 -98.447688
# 3  'River house on island close to the city' \nA ...  29.829352 -95.081549
# 4  Private bedroom in a cute little home situated...  30.637304 -96.337846
# 5  Welcome to our original 1920's home. We recent...  32.747097 -97.286434
#
#                                                title  \
# ...

# %%
#Q8
bools=airbnb['average_rate_per_night']<0.
bools.any()
# Out:
# False

# %%
airbnb['average_rate_per_night'].mean()
# Out:
# 211.5589752029844

# %%
#Q9
airbnb['bedrooms_count'].unique()
# Out:
# array(['2', '4', '1', '3', 'Studio', '7', '5', '8', '6', '9', '11', '13',
#        '10'], dtype=object)

# %%
#Q10
(airbnb['bedrooms_count']=='Studio').any()
# Out:
# True

# %%
rate=airbnb['average_rate_per_night']

# %%
rate[airbnb['bedrooms_count']=='Studio'].mean()
# Out:
# 106.34375

# %%
#Q11
maxbed=airbnb['bedrooms_count'].replace('Studio','0').astype(int).max()
maxbed
# Out:
# 13

# %%
rate[airbnb['bedrooms_count']=='13'].mean()
# Out:
# 3049.0

# %%
#Q12
rate[(airbnb['bedrooms_count']=='2') & (airbnb['city']=='Houston')].max()
# Out:
# 6250

# %%
rate[(airbnb['bedrooms_count']=='2') & (airbnb['city']=='Houston')].min()
# Out:
# 36

# %%
rate[(airbnb['bedrooms_count']=='2') & (airbnb['city']=='Houston')].mean()
# Out:
# 307.0287081339713
